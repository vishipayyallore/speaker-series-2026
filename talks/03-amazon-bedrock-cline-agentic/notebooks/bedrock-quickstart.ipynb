# %% [markdown]
# # Bedrock quickstart
#
# Companion notebook for [03-amazon-bedrock-cline-agentic](../README.md).
#
# 1. Copy `.env.example` from the repo root to `.env` and set AWS credentials.
# 2. Install dependencies: `pip install boto3 python-dotenv`
# 3. Run cells in order.

# %%
import sys
from pathlib import Path

src = Path('../src').resolve()
sys.path.insert(0, str(src))

from bedrock_client import invoke

invoke('What is a foundation model in one sentence?')
# Out:
# Running cells with 'speaker-series-2026 (3.12.10) (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/GitHub/speaker-series-2026/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
